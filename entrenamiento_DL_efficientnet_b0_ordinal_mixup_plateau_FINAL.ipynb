# %% [markdown]
# # Gu?a r?pida para generar la tabla
#
# Ejecuta las secciones **1 a 9**. Despu?s de la secci?n 9 ya tendr?s los dos CSV de la tesis. La secci?n **10** es opcional y puedes saltarla.

# %% [markdown]
# # 0. Verificaci?n r?pida - OPCIONAL
#
# Sirve para confirmar versi?n de PyTorch y si CUDA est? disponible. Puedes saltarla.

# %%
import torch

# %%
torch.__version__
# Out:
# '2.10.0+cu128'

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# # 1. Imports base - EJECUTAR
#
# Carga librer?as generales necesarias.

# %%
import os, re, time, json, random, math, gc
from pathlib import Path
import numpy as np
import pandas as pd
from PIL import Image

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import models, transforms
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from pathlib import Path
from tqdm import tqdm

import timm

# %% [markdown]
# # 2. Preprocesamiento de im?genes - EJECUTAR
#
# Define funciones para recorte de fondo de ojo y CLAHE.

# %%
# --- PRE/POSTPROCESADO de fondo de ojo ---
import cv2
from PIL import Image

def crop_fundus_rgb(im_pil: Image.Image) -> Image.Image:
    arr = np.array(im_pil)
    g = cv2.cvtColor(arr, cv2.COLOR_RGB2GRAY)
    m = (g > 5).astype(np.uint8) * 255
    cnts, _ = cv2.findContours(m, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if not cnts:
        return im_pil
    cnt = max(cnts, key=cv2.contourArea)
    (cx, cy), r = cv2.minEnclosingCircle(cnt)   
    cx, cy, r = int(cx), int(cy), int(r * 0.98)
    x0, x1 = max(0, cx - r), min(arr.shape[1], cx + r)
    y0, y1 = max(0, cy - r), min(arr.shape[0], cy + r)
    arr = arr[y0:y1, x0:x1]
    return Image.fromarray(arr)

def clahe_green(im_pil: Image.Image) -> Image.Image:
    arr = np.array(im_pil)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    arr[..., 1] = clahe.apply(arr[..., 1])  # canal G
    return Image.fromarray(arr)

# %% [markdown]
# # 3. Configuraci?n del experimento - EJECUTAR
#
# Define `DATA_ROOT`, `ARCH`, `IMG_SIZE`, `OUTDIR`, `DEVICE` y par?metros principales.

# %%
# ----------------------------
# CONFIG
# ----------------------------
DATA_ROOT   = Path(r"C:\Users\Victoria\Desktop\data\datos_raw")  # <- ajusta si cambiaste
DATASETS    = ["aptos_2019", "eyePACS", "idrid"]     # usa los que tengas
ARCH        = "efficientnet_b0"                           # "resnet34"|"efficientnet_b0"|"mobilenet_v3_large"|"inception_v3"

# ↑ Para probar "más resolución" como sugirió tu asesor:
IMG_SIZE    = 384   # prueba 384 o 448 (ojo: sube el uso de VRAM)

N_CLASSES   = 5

BATCH_BASE  = 16             # si falta VRAM con IMG_SIZE grande, baja a 8 o 4
BATCH       = max(1, BATCH_BASE // 2)
EPOCHS      = 25
LR          = 1e-4
WD          = 5e-2
SEED        = 42
NUM_WORKERS = 0
PIN_MEMORY  = True

# --------- Split por dataset (generalización)
# None  -> split interno estratificado (como antes)
# "messidor" / "eyePACS" / "aptos_2019" / "idrid" -> train con 3 BD y val con 1 BD
HOLDOUT_DATASET = None

VAL_SIZE    = 0.15                  # proporción de validación desde train (solo si HOLDOUT_DATASET=None)
USE_CLASS_WEIGHTS     = True
EARLY_STOP_PATIENCE   = 5
BALANCE_MAX_PER_CLASS = 991        # None = sin tope; recomendable 500-1000 para que eyePACS no domine

# --------- Ordinalidad (clases 0-4 con "gradualidad")
# "ce"       -> CrossEntropy normal
# "soft_ce"  -> CE con targets "suaves" (penaliza menos si te equivocas por 1 clase)
LOSS_TYPE = "soft_ce"
SOFT_CE_TAU = 1.0   # más alto = más suave (0.7–1.5 suele ir bien)

# --------- MixUp / CutMix (opcional)
USE_MIXUP  = True
MIXUP_ALPHA  = 0.2    # 0.2–0.4 suele ser estable
CUTMIX_ALPHA = 0.0    # si quieres CutMix, pon 0.2 y USE_MIXUP=True

# ====== RUTA DE SALIDA PARA TUS RESULTADOS ======
BASE_OUT = Path(r"C:\Users\Victoria\Desktop\data\datos_raw\resultados_dl")

RUN_TAG  = f"{ARCH}_img{IMG_SIZE}_bs{BATCH}_lr{LR}_rerun".replace("/", "-")
OUTDIR   = BASE_OUT / f"COMBINED_TRAIN_ONLY_{'-'.join(DATASETS)}_{RUN_TAG}"
OUTDIR.mkdir(parents=True, exist_ok=True)

torch.backends.cudnn.benchmark = True
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def set_seed(s=SEED):
    random.seed(s); np.random.seed(s); torch.manual_seed(s); torch.cuda.manual_seed_all(s)
set_seed(SEED)
print("Device:", DEVICE)
print("OUTDIR:", OUTDIR)
# Out:
# Device: cuda
# OUTDIR: C:\Users\Victoria\Desktop\data\datos_raw\resultados_dl\COMBINED_TRAIN_ONLY_aptos_2019-eyePACS-idrid_efficientnet_b0_img384_bs8_lr0.0001_rerun

# %% [markdown]
# # 4. Carga y uni?n de datasets - EJECUTAR
#
# Lee APTOS 2019, EyePACS, IDRiD y Messidor, normaliza columnas y construye `df_all`.

# %%
# ----------------------------
# Utilidades
# ----------------------------
IMAGE_COL_CANDIDATES = {"image","filename","file","img","imagen","Image","File","Filename"}
LABEL_COL_CANDIDATES = {"level","label","labels","grade","diagnosis","target","class","DR","DRGrade","Severity"}

def resolve_img(basename: str, folder: Path):
    exts = (".png",".jpg",".jpeg",".tif",".tiff",".bmp",".JPG",".JPEG",".PNG")
    s = str(basename)
    if any(s.endswith(e) for e in exts):
        p = folder / s
        return str(p) if p.exists() else None
    for e in exts:
        p = folder / f"{s}{e}"
        if p.exists():
            return str(p)
    return None

def read_train_only(dataset_name: str):
    root = DATA_ROOT / dataset_name
    csv_path = root / "train.csv"
    if not csv_path.exists():
        print(f"[AVISO] {dataset_name} no tiene train.csv")
        return None
    df = pd.read_csv(csv_path)
    # columnas
    img_col = None
    for c in df.columns:
        if c in IMAGE_COL_CANDIDATES or c.lower() in {x.lower() for x in IMAGE_COL_CANDIDATES}:
            img_col = c; break
    if img_col is None:
        for c in df.columns:
            if re.search(r"(image|file|name|img)", c, re.I):
                img_col = c; break
    if img_col is None:
        print(f"[AVISO] {csv_path} no tiene columna de imagen")
        return None

    y_col = None
    for c in df.columns:
        if c in LABEL_COL_CANDIDATES or c.lower() in {x.lower() for x in LABEL_COL_CANDIDATES}:
            y_col = c; break
    if y_col is None:
        print(f"[AVISO] {csv_path} no tiene columna de etiqueta (level/label/grade/...)")
        return None

    df = df[[img_col, y_col]].copy()
    df.rename(columns={img_col:"image", y_col:"level"}, inplace=True)
    df["image"] = df["image"].astype(str)

    # carpetas típicas de imágenes
    img_dirs = [root/"train", root/"images/train", root]
    img_dir = None
    for d in img_dirs:
        if d.exists():
            img_dir = d; break
    if img_dir is None:
        # fallback: carpeta con más imágenes
        cand = [p for p in root.rglob("*") if p.is_dir()]
        best, best_cnt = None, -1
        for p in cand:
            cnt = len([q for q in p.glob("*.*") if q.suffix.lower() in (".png",".jpg",".jpeg",".tif",".tiff",".bmp")])
            if cnt > best_cnt:
                best, best_cnt = p, cnt
        img_dir = best if best is not None else root

    df["path"] = df["image"].apply(lambda s: resolve_img(s, img_dir))
    df = df.dropna(subset=["path"]).reset_index(drop=True)
    # normaliza etiqueta a int
    df["level"] = pd.to_numeric(df["level"], errors="coerce").astype("Int64")
    df = df.dropna(subset=["level"]).astype({"level": int})
    df["dataset"] = dataset_name

    print(f"[OK] {dataset_name}/train → filas={len(df)} | img_dir={img_dir.relative_to(DATA_ROOT) if str(img_dir).startswith(str(DATA_ROOT)) else img_dir}")
    return df

# Combinar todos los train
parts = []
for ds in DATASETS:
    out = read_train_only(ds)
    if out is not None and len(out):
        parts.append(out)
assert parts, "No se encontró ningún train.csv válido."
df_all = pd.concat(parts, ignore_index=True)

# Balanceo global opcional
if BALANCE_MAX_PER_CLASS is not None:
    before = df_all["level"].value_counts().sort_index().to_dict()
    df_all = (df_all.groupby("level", group_keys=False)
                     .apply(lambda g: g.sample(min(len(g), BALANCE_MAX_PER_CLASS), random_state=SEED))
                     ).reset_index(drop=True)
    after  = df_all["level"].value_counts().sort_index().to_dict()
    print("\nBalanceo global (tope por clase):")
    print("Antes :", before)
    print("Después:", after)

print("\nTamaño total combinado:", len(df_all))
print("Distribución:", df_all["level"].value_counts().sort_index().to_dict())

print("\nDistribución por dataset después del balanceo:")
print(df_all["dataset"].value_counts().sort_index())

print("\nDistribución por dataset y clase después del balanceo:")
print(pd.crosstab(df_all["dataset"], df_all["level"]))
# Out:
# [OK] aptos_2019/train → filas=2930 | img_dir=aptos_2019\train
# [OK] eyePACS/train → filas=35126 | img_dir=eyePACS\train
# [OK] idrid/train → filas=413 | img_dir=idrid\train
#
# Balanceo global (tope por clase):
# Antes : {0: 27378, 1: 2763, 2: 6236, 3: 1101, 4: 991}
# Después: {0: 991, 1: 991, 2: 991, 3: 991, 4: 991}
#
# Tamaño total combinado: 4955
# Distribución: {0: 991, 1: 991, 2: 991, 3: 991, 4: 991}
#
# Distribución por dataset después del balanceo:
# dataset
# aptos_2019     664
# eyePACS       4131
# idrid          160
# Name: count, dtype: int64
#
# Distribución por dataset y clase después del balanceo:
# level         0    1    2    3    4
# dataset
# aptos_2019   35  109  148  138  234
# eyePACS     949  871  819  784  708
# idrid         7   11   24   69   49
# C:\Users\Victoria\AppData\Local\Temp\ipykernel_17448\2160475542.py:90: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: g.sample(min(len(g), BALANCE_MAX_PER_CLASS), random_state=SEED))

# %% [markdown]
# # 5. Split train/validaci?n - EJECUTAR
#
# Crea `df_tr` y `df_va`. La tabla final usa `df_va`.

# %%
# ----------------------------
# Split train/val
# ----------------------------
if HOLDOUT_DATASET is not None:
    assert HOLDOUT_DATASET in set(df_all["dataset"]), f"HOLDOUT_DATASET inválido: {HOLDOUT_DATASET}"
    df_tr = df_all[df_all["dataset"] != HOLDOUT_DATASET].reset_index(drop=True)
    df_va = df_all[df_all["dataset"] == HOLDOUT_DATASET].reset_index(drop=True)

    print(f"\nHoldout por dataset → HOLDOUT={HOLDOUT_DATASET}")
    print(f"Train (3 BD) = {len(df_tr)} | Val (1 BD) = {len(df_va)}")
else:
    from sklearn.model_selection import StratifiedShuffleSplit
    sss = StratifiedShuffleSplit(n_splits=1, test_size=VAL_SIZE, random_state=SEED)
    idx_tr, idx_va = next(sss.split(df_all["path"].values, df_all["level"].values))
    df_tr = df_all.iloc[idx_tr].reset_index(drop=True)
    df_va = df_all.iloc[idx_va].reset_index(drop=True)

    print(f"\nSplit interno (estratificado) → train={len(df_tr)} | val={len(df_va)}")

print("Dist. train:", df_tr["level"].value_counts().sort_index().to_dict())
print("Dist. val  :", df_va["level"].value_counts().sort_index().to_dict())
print("Datasets train:", df_tr["dataset"].value_counts().to_dict())
print("Datasets val  :", df_va["dataset"].value_counts().to_dict())


print("\nDistribución por clase en entrenamiento:")
print(df_tr["level"].value_counts().sort_index())

print("\nDistribución por clase en validación:")
print(df_va["level"].value_counts().sort_index())

print("\nDistribución por dataset en entrenamiento:")
print(df_tr["dataset"].value_counts().sort_index())

print("\nDistribución por dataset en validación:")
print(df_va["dataset"].value_counts().sort_index())

print("\nTabla final por dataset:")
tabla_dataset = pd.DataFrame({
    "Entrenamiento": df_tr["dataset"].value_counts().sort_index(),
    "Validación": df_va["dataset"].value_counts().sort_index()
}).fillna(0).astype(int)
tabla_dataset["Total usado en el Experimento 1"] = tabla_dataset["Entrenamiento"] + tabla_dataset["Validación"]
print(tabla_dataset)

print("\nTabla final por clase:")
tabla_clase = pd.DataFrame({
    "Entrenamiento": df_tr["level"].value_counts().sort_index(),
    "Validación": df_va["level"].value_counts().sort_index()
}).fillna(0).astype(int)
tabla_clase["Total"] = tabla_clase["Entrenamiento"] + tabla_clase["Validación"]
print(tabla_clase)
# Out:
# Split interno (estratificado) → train=4211 | val=744
# Dist. train: {0: 842, 1: 843, 2: 842, 3: 842, 4: 842}
# Dist. val  : {0: 149, 1: 148, 2: 149, 3: 149, 4: 149}
# Datasets train: {'eyePACS': 3517, 'aptos_2019': 559, 'idrid': 135}
# Datasets val  : {'eyePACS': 614, 'aptos_2019': 105, 'idrid': 25}
#
# Distribución por clase en entrenamiento:
# level
# 0    842
# 1    843
# 2    842
# 3    842
# 4    842
# Name: count, dtype: int64
#
# Distribución por clase en validación:
# level
# 0    149
# 1    148
# 2    149
# 3    149
# 4    149
# Name: count, dtype: int64
#
# Distribución por dataset en entrenamiento:
# dataset
# aptos_2019     559
# eyePACS       3517
# idrid          135
# Name: count, dtype: int64
#
# Distribución por dataset en validación:
# dataset
# aptos_2019    105
# eyePACS       614
# idrid          25
# Name: count, dtype: int64
#
# Tabla final por dataset:
#             Entrenamiento  Validación  Total usado en el Experimento 1
# dataset
# aptos_2019            559         105                              664
# eyePACS              3517         614                             4131
# idrid                 135          25                              160
#
# Tabla final por clase:
#        Entrenamiento  Validación  Total
# level
# 0                842         149    991
# 1                843         148    991
# 2                842         149    991
# 3                842         149    991
# 4                842         149    991

# %% [markdown]
# # 6. Dataset y DataLoader - EJECUTAR
#
# Define `CSVImages`, las transformaciones y `dl_va`.

# %%
# ----------------------------
# Dataset + transforms
# ----------------------------
IMAGENET_MEAN = (0.485, 0.456, 0.406)
IMAGENET_STD  = (0.229, 0.224, 0.225)

from torchvision.transforms import InterpolationMode

# Nota (según sugerencia del asesor):
# Eliminamos: GaussianBlur, RandomResizedCrop, RandomErasing
# Dejamos augmentations "seguros" + crop ligero para mantener FOV sin distorsión fuerte.

tfm_tr = transforms.Compose([
    transforms.Resize(int(IMG_SIZE * 1.05), interpolation=InterpolationMode.BILINEAR),
    transforms.CenterCrop(IMG_SIZE),
    transforms.RandomRotation(15, interpolation=InterpolationMode.BILINEAR),
    transforms.RandomHorizontalFlip(),
    transforms.RandomApply([transforms.ColorJitter(0.2, 0.2, 0.2, 0.1)], p=0.7),
    transforms.RandomAutocontrast(p=0.3),
    transforms.ToTensor(),
    transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD),
])

tfm_va = transforms.Compose([
    transforms.Resize(IMG_SIZE, interpolation=InterpolationMode.BILINEAR),
    transforms.CenterCrop(IMG_SIZE),
    transforms.ToTensor(),
    transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD),
])

class CSVImages(Dataset):
    def __init__(self, df, tfm, do_fov_crop=True, do_clahe=True):
        self.df = df.reset_index(drop=True)
        self.tfm = tfm
        self.do_fov_crop = do_fov_crop
        self.do_clahe = do_clahe

    def __len__(self):
        return len(self.df)

    def __getitem__(self, i):
        r = self.df.iloc[i]
        im = Image.open(r["path"]).convert("RGB")
        if self.do_fov_crop:
            im = crop_fundus_rgb(im)
        if self.do_clahe:
            im = clahe_green(im)
        im = self.tfm(im)
        return im, int(r["level"])

dl_tr = DataLoader(CSVImages(df_tr, tfm_tr),
                   batch_size=BATCH, shuffle=True,
                   num_workers=NUM_WORKERS, pin_memory=PIN_MEMORY)

dl_va = DataLoader(CSVImages(df_va, tfm_va),
                   batch_size=BATCH, shuffle=False,
                   num_workers=NUM_WORKERS, pin_memory=PIN_MEMORY)

# %% [markdown]
# # 7. Modelo y checkpoint - EJECUTAR
#
# Define `build_model`. Si encuentra `best.pth`, carga el checkpoint y no reentrena.

# %%
# ----------------------------
# Modelo + Loss + Optimizer + Scheduler
# ----------------------------
from sklearn.metrics import cohen_kappa_score
from transformers import SegformerForImageClassification

def build_model(arch: str, n_classes: int):

    if arch in ["mit_b0", "mit_b1"]:
        hf_id = "nvidia/mit-b0" if arch == "mit_b0" else "nvidia/mit-b1"
        m = SegformerForImageClassification.from_pretrained(
            hf_id,
            num_labels=n_classes,
            ignore_mismatched_sizes=True  # reemplaza head a 5 clases
        )
        return m

    if arch == "resnet34":
        try:
            m = models.resnet34(weights=models.ResNet34_Weights.IMAGENET1K_V1)
        except Exception:
            m = models.resnet34(pretrained=True)
        m.fc = nn.Linear(m.fc.in_features, n_classes)
    elif arch == "resnet50":
        m = models.resnet50(weights=models.ResNet50_Weights.IMAGENET1K_V2)
        m.fc = nn.Linear(m.fc.in_features, n_classes)
    elif arch == "efficientnet_b0":
        m = models.efficientnet_b0(weights=models.EfficientNet_B0_Weights.IMAGENET1K_V1)
        m.classifier[1] = nn.Linear(m.classifier[1].in_features, n_classes)
    elif arch == "mobilenet_v3_large":
        m = models.mobilenet_v3_large(weights=models.MobileNet_V3_Large_Weights.IMAGENET1K_V2)
        m.classifier[-1] = nn.Linear(m.classifier[-1].in_features, n_classes)
    elif arch == "inception_v3":
        m = models.inception_v3(weights=models.Inception_V3_Weights.IMAGENET1K_V1, aux_logits=True)
        m.fc = nn.Linear(m.fc.in_features, n_classes)
        m.aux_logits = False
    else:
        raise ValueError(f"Arquitectura no soportada: {arch}")
    return m

model = build_model(ARCH, N_CLASSES).to(DEVICE)

def class_weights_from_df(df, n_classes=N_CLASSES):
    cnt = df["level"].value_counts().reindex(range(n_classes), fill_value=0).values.astype(np.float32)
    cnt[cnt==0] = 1.0
    w = cnt.sum() / (cnt * len(cnt))
    return torch.tensor(w, dtype=torch.float32)

# ----- Loss ordinal-friendly (soft labels)
def soft_targets(y: torch.Tensor, n_classes: int, tau: float = 1.0) -> torch.Tensor:
    """
    Crea targets suaves con forma (B, C).
    Penaliza menos si el modelo se equivoca por clases cercanas.
    """
    # distancias |k - y|
    k = torch.arange(n_classes, device=y.device).float()[None, :]  # (1,C)
    y = y.float()[:, None]  # (B,1)
    dist = torch.abs(k - y)
    p = torch.exp(-dist / max(1e-6, tau))
    p = p / p.sum(dim=1, keepdim=True)
    return p

def soft_ce_loss(logits: torch.Tensor, y: torch.Tensor, tau: float = 1.0, class_w: torch.Tensor | None = None):
    """
    CrossEntropy con targets suaves (equivalente a KL(log_softmax, soft_target)).
    """
    logp = torch.log_softmax(logits, dim=1)
    tgt = soft_targets(y, logits.size(1), tau=tau)
    if class_w is not None:
        # ponderación por clase: multiplica el target por w(k) y renormaliza
        w = class_w[None, :].to(logits.device)
        tgt = tgt * w
        tgt = tgt / tgt.sum(dim=1, keepdim=True).clamp_min(1e-9)
    loss = -(tgt * logp).sum(dim=1).mean()
    return loss

# Loss final
class_w = class_weights_from_df(df_tr).to(DEVICE) if USE_CLASS_WEIGHTS else None

if LOSS_TYPE == "ce":
    criterion = nn.CrossEntropyLoss(weight=class_w) if USE_CLASS_WEIGHTS else nn.CrossEntropyLoss()
elif LOSS_TYPE == "soft_ce":
    criterion = None  # lo calcularemos manualmente con soft_ce_loss
else:
    raise ValueError(f"LOSS_TYPE no soportado: {LOSS_TYPE}")

optimizer = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=WD)

# Scheduler recomendado por el asesor: ReduceLROnPlateau (reduce LR cuando val_loss se estanca)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode="min",
    factor=0.5, patience=2, threshold=1e-4,
    min_lr=1e-6
)

scaler = torch.cuda.amp.GradScaler(enabled=(DEVICE.type=="cuda"))

# ----------------------------
# MixUp / CutMix (opcional)
# ----------------------------
def rand_bbox(W, H, lam):
    cut_rat = np.sqrt(1. - lam)
    cut_w = int(W * cut_rat)
    cut_h = int(H * cut_rat)

    cx = np.random.randint(W)
    cy = np.random.randint(H)

    x1 = np.clip(cx - cut_w // 2, 0, W)
    y1 = np.clip(cy - cut_h // 2, 0, H)
    x2 = np.clip(cx + cut_w // 2, 0, W)
    y2 = np.clip(cy + cut_h // 2, 0, H)
    return x1, y1, x2, y2

def apply_mixup_cutmix(x, y, alpha_mixup=0.2, alpha_cutmix=0.0):
    """
    Retorna: x_aug, y_a, y_b, lam, mode
    mode = "mixup" / "cutmix" / None
    """
    if (alpha_mixup <= 0) and (alpha_cutmix <= 0):
        return x, y, y, 1.0, None

    r = np.random.rand()
    use_cutmix = (alpha_cutmix > 0) and (r < 0.5)

    if use_cutmix:
        lam = np.random.beta(alpha_cutmix, alpha_cutmix)
        idx = torch.randperm(x.size(0), device=x.device)
        y_a, y_b = y, y[idx]

        _, _, H, W = x.size()
        x1, y1, x2, y2 = rand_bbox(W, H, lam)
        x_aug = x.clone()
        x_aug[:, :, y1:y2, x1:x2] = x[idx, :, y1:y2, x1:x2]
        # ajustar lambda exacto por área
        lam = 1.0 - ((x2 - x1) * (y2 - y1) / (W * H))
        return x_aug, y_a, y_b, lam, "cutmix"

    # MixUp
    lam = np.random.beta(alpha_mixup, alpha_mixup) if alpha_mixup > 0 else 1.0
    idx = torch.randperm(x.size(0), device=x.device)
    x_aug = lam * x + (1 - lam) * x[idx]
    y_a, y_b = y, y[idx]
    return x_aug, y_a, y_b, lam, "mixup"

# ----------------------------
# Train / Eval
# ----------------------------
best_val, best_ep, patience = float("inf"), -1, EARLY_STOP_PATIENCE

def compute_loss(logits, y):
    if LOSS_TYPE == "ce":
        return criterion(logits, y)
    # soft_ce
    return soft_ce_loss(logits, y, tau=SOFT_CE_TAU, class_w=class_w)

def run_epoch(loader, train=True):
    model.train(train)
    tot, n = 0.0, 0
    pbar = tqdm(loader, desc=f"{'Train' if train else 'Val  '}", leave=False, disable=False)

    for xb, yb in pbar:
        xb = xb.to(DEVICE, non_blocking=True)
        yb = yb.to(DEVICE, non_blocking=True)

        if train:
            optimizer.zero_grad(set_to_none=True)

            # MixUp/CutMix (solo en train)
            if USE_MIXUP:
                xb, ya, yb2, lam, mode = apply_mixup_cutmix(
                    xb, yb, alpha_mixup=MIXUP_ALPHA, alpha_cutmix=CUTMIX_ALPHA
                )
            else:
                ya, yb2, lam = yb, yb, 1.0

            with torch.cuda.amp.autocast(enabled=(DEVICE.type=="cuda")):
                logits = model(xb)

                if USE_MIXUP and lam < 1.0:
                    loss = lam * compute_loss(logits, ya) + (1 - lam) * compute_loss(logits, yb2)
                else:
                    loss = compute_loss(logits, yb)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

        else:
            with torch.no_grad():
                logits = model(xb)
                loss = compute_loss(logits, yb)

        tot += loss.item() * yb.size(0)
        n += yb.size(0)
        pbar.set_postfix({"loss": f"{tot/n:.4f}"})

    return tot / max(1, n)

def eval_metrics(loader):
    model.eval()
    tot, n = 0.0, 0
    all_preds, all_true = [], []
    with torch.no_grad():
        for xb, yb in loader:
            xb = xb.to(DEVICE, non_blocking=True)
            yb = yb.to(DEVICE, non_blocking=True)
            if ARCH in ["mit_b0", "mit_b1"]:
                logits = model(pixel_values=xb).logits
            else:
                logits = model(xb)

            loss = compute_loss(logits, yb)
            tot += loss.item() * yb.size(0); n += yb.size(0)

            preds = logits.argmax(1)
            all_preds.append(preds.detach().cpu())
            all_true.append(yb.detach().cpu())

    y = torch.cat(all_true).numpy()
    p = torch.cat(all_preds).numpy()
    val_loss = tot / max(1, n)
    val_acc = (p == y).mean()

    # Métrica "ordinal" rápida (como te sugirió tu asesor)
    kappa_qwk = cohen_kappa_score(y, p, weights="quadratic")
    return val_loss, val_acc, float(kappa_qwk), y, p

class_names = ["No DR","Mild","Moderate","Severe","Proliferative"]

BEST_CKPT = OUTDIR / "best.pth"
if BEST_CKPT.exists():
    print(f"[SKIP TRAIN] Ya existe checkpoint entrenado: {BEST_CKPT}")
    state = torch.load(BEST_CKPT, map_location=DEVICE)
    model.load_state_dict(state)
    model.eval()
    print(f"Modelo cargado sin reentrenar: {BEST_CKPT}")
else:
    print(f"\n{'='*60}")
    print(f"Iniciando entrenamiento: {ARCH} | {EPOCHS} épocas | IMG {IMG_SIZE} | BS {BATCH} | LR {LR} | LOSS {LOSS_TYPE}")
    print(f"{'='*60}\n")

    for ep in range(1, EPOCHS+1):
        t0 = time.time()

        ltr = run_epoch(dl_tr, train=True)
        lva, vacc, vkappa, ys, ps = eval_metrics(dl_va)

        log_dict = {
            "epoch": ep,
            "train/loss": float(ltr),
            "val/loss":   float(lva),
            "val/acc":    float(vacc),
            "val/qwk":    float(vkappa),
            "lr":         float(optimizer.param_groups[0]["lr"]),
        }

        if ep % 2 == 0:
            try:
                log_dict["val/confusion_matrix"] = wandb.plot.confusion_matrix(
                    y_true=ys, preds=ps, class_names=class_names
                )
            except Exception as e:
                print(f"[W&B] No se pudo loguear CM en epoch {ep}: {e}")

        try:
            wandb.log(log_dict)
        except Exception as e:
            print(f"[W&B] Error en wandb.log en epoch {ep}: {e}")

        if lva < best_val:
            best_val, best_ep = lva, ep
            torch.save(model.state_dict(), OUTDIR/"best.pth")
            patience = EARLY_STOP_PATIENCE
            print(f"[Ep {ep:02d}/{EPOCHS}] loss_tr={ltr:.4f} | loss_val={lva:.4f} | acc={vacc:.4f} | qwk={vkappa:.4f} | {time.time()-t0:.1f}s [NEW BEST]")
        else:
            patience -= 1
            print(f"[Ep {ep:02d}/{EPOCHS}] loss_tr={ltr:.4f} | loss_val={lva:.4f} | acc={vacc:.4f} | qwk={vkappa:.4f} | {time.time()-t0:.1f}s (patience: {patience})")

        # ReduceLROnPlateau debe ver el val_loss
        scheduler.step(lva)

        if patience <= 0:
            print(f"\n[EARLY STOP] Parada anticipada en ep {ep} (mejor: ep {best_ep})")
            break

    print(f"\n{'='*60}")
    print(f"Entrenamiento finalizado. Mejor época: {best_ep} con val_loss {best_val:.4f}")
    print(f"{'='*60}\n")

    if (OUTDIR/"best.pth").exists():
        model.load_state_dict(torch.load(OUTDIR/"best.pth", map_location=DEVICE))
        print(f"Modelo cargado: {OUTDIR/'best.pth'}")
    else:
        torch.save(model.state_dict(), OUTDIR/"last.pth")
        print(f"Modelo guardado: {OUTDIR/'last.pth'}")
# Out:
# [SKIP TRAIN] Ya existe checkpoint entrenado: C:\Users\Victoria\Desktop\data\datos_raw\resultados_dl\COMBINED_TRAIN_ONLY_aptos_2019-eyePACS-idrid_efficientnet_b0_img384_bs8_lr0.0001_rerun\best.pth
# Modelo cargado sin reentrenar: C:\Users\Victoria\Desktop\data\datos_raw\resultados_dl\COMBINED_TRAIN_ONLY_aptos_2019-eyePACS-idrid_efficientnet_b0_img384_bs8_lr0.0001_rerun\best.pth
# C:\Users\Victoria\AppData\Local\Temp\ipykernel_17448\2743059974.py:96: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=(DEVICE.type=="cuda"))

# %% [markdown]
# # 8. Funci?n de inferencia - EJECUTAR
#
# Define `eval_collect`. Esta celda debe correr r?pido porque solo define la funci?n.

# %%
# ========= Eval: recolectar y_true, y_pred, y_prob =========
import torch
import numpy as np

@torch.no_grad()
def eval_collect(model, loader, device):
    """Recolecta y_true, y_pred, y_prob desde `loader`.

    Notas:
    - Movemos batchs a `device` (GPU) para hacer forward. Las probabilidades/predicciones
      se llevan a CPU y se concatenan una sola vez para ahorrar overhead por batch.
    - Esto NO modifica el modelo ni los gradientes.
    """
    model.eval()
    all_prob, all_pred, all_true = [], [], []
    for x, y in loader:
        x = x.to(device, non_blocking=True)
        y = y.to(device, non_blocking=True)
        # forward (AMP opcional en validación si quieres)
        if ARCH in ["mit_b0", "mit_b1"]:
            logits = model(pixel_values=x).logits
        else:
            logits = model(x)

        prob = torch.softmax(logits, dim=1)
        pred = prob.argmax(dim=1)
        # mover a CPU para almacenamiento/numpy (concatenamos al final)
        all_prob.append(prob.detach().cpu().numpy())
        all_pred.append(pred.detach().cpu().numpy())
        all_true.append(y.detach().cpu().numpy())
    y_prob = np.concatenate(all_prob, axis=0)     # (N, C)
    y_pred = np.concatenate(all_pred, axis=0)     # (N,)
    y_true = np.concatenate(all_true, axis=0)     # (N,)
    return y_true, y_pred, y_prob

# Nota: la inferencia se ejecuta en la celda final de la tabla por dataset.

# %% [markdown]
# # 9. Tabla de estabilidad por dataset - EJECUTAR
#
# Esta es la celda final importante. Genera `predicciones_validacion_efficientnet_b0_por_dataset.csv` y `tabla_estabilidad_por_dataset_efficientnet_b0.csv`. Puede demorar unos minutos porque hace inferencia sobre validaci?n.

# %%
# ========= Tabla de estabilidad por procedencia del dato (EfficientNet-B0) =========
from pathlib import Path
import numpy as np
import pandas as pd
import torch
from sklearn.metrics import accuracy_score, f1_score, recall_score, cohen_kappa_score

# Usar el checkpoint entrenado del experimento actual; no reentrena.
OUTDIR = Path(OUTDIR)
BEST_CKPT = OUTDIR / "best.pth"
if not BEST_CKPT.exists():
    raise FileNotFoundError(f"No existe el checkpoint entrenado: {BEST_CKPT}")

if ARCH != "efficientnet_b0":
    raise ValueError(f"Esta tabla corresponde a EfficientNet-B0, pero ARCH={ARCH!r}.")

# Cargar pesos entrenados solo para inferencia.
model = build_model("efficientnet_b0", N_CLASSES).to(DEVICE)
state = torch.load(BEST_CKPT, map_location=DEVICE)
model.load_state_dict(state)
model.eval()

# Obtener predicciones de validaci?n con la funci?n ya definida en el notebook.
y_true, y_pred, y_prob = eval_collect(model, dl_va, DEVICE)

if len(df_va) != len(y_true):
    raise ValueError(f"df_va tiene {len(df_va)} filas, pero y_true tiene {len(y_true)} predicciones.")

columnas_base = [c for c in ["path", "dataset", "level"] if c in df_va.columns]
faltantes = {"dataset", "level"} - set(columnas_base)
if faltantes:
    raise KeyError(f"Faltan columnas necesarias en df_va: {sorted(faltantes)}")

df_pred_val = df_va[columnas_base].copy().reset_index(drop=True)
if "path" not in df_pred_val.columns:
    df_pred_val.insert(0, "path", np.nan)

df_pred_val["y_true"] = np.asarray(y_true, dtype=int)
df_pred_val["y_pred"] = np.asarray(y_pred, dtype=int)

df_pred_val.to_csv(
    OUTDIR / "predicciones_validacion_efficientnet_b0_por_dataset.csv",
    index=False
)

filas = []
for dataset, g in df_pred_val.groupby("dataset", sort=False):
    y_t = g["y_true"].to_numpy()
    y_p = g["y_pred"].to_numpy()

    recalls = recall_score(
        y_t,
        y_p,
        labels=[0, 1, 2, 3, 4],
        average=None,
        zero_division=0
    )

    filas.append({
        "Modelo": "EfficientNet-B0",
        "Dataset": dataset,
        "N validaci?n": len(g),
        "Accuracy": accuracy_score(y_t, y_p),
        "F1 macro": f1_score(y_t, y_p, average="macro", zero_division=0),
        "Recall clase 3": recalls[3],
        "Recall clase 4": recalls[4],
        "QWK": cohen_kappa_score(y_t, y_p, weights="quadratic")
    })

tabla_estabilidad_effnet = pd.DataFrame(filas)
cols_metricas = ["Accuracy", "F1 macro", "Recall clase 3", "Recall clase 4", "QWK"]
tabla_estabilidad_effnet[cols_metricas] = tabla_estabilidad_effnet[cols_metricas].round(3)

orden = ["aptos_2019", "eyePACS", "idrid", "messidor"]
tabla_estabilidad_effnet["orden"] = tabla_estabilidad_effnet["Dataset"].apply(
    lambda x: orden.index(x) if x in orden else 99
)
tabla_estabilidad_effnet = tabla_estabilidad_effnet.sort_values("orden").drop(columns="orden")

tabla_estabilidad_effnet.to_csv(
    OUTDIR / "tabla_estabilidad_por_dataset_efficientnet_b0.csv",
    index=False
)

print("Archivos generados:")
print("-", OUTDIR / "predicciones_validacion_efficientnet_b0_por_dataset.csv")
print("-", OUTDIR / "tabla_estabilidad_por_dataset_efficientnet_b0.csv")

tabla_estabilidad_effnet
# Out:
# Archivos generados:
# - C:\Users\Victoria\Desktop\data\datos_raw\resultados_dl\COMBINED_TRAIN_ONLY_aptos_2019-eyePACS-idrid_efficientnet_b0_img384_bs8_lr0.0001_rerun\predicciones_validacion_efficientnet_b0_por_dataset.csv
# - C:\Users\Victoria\Desktop\data\datos_raw\resultados_dl\COMBINED_TRAIN_ONLY_aptos_2019-eyePACS-idrid_efficientnet_b0_img384_bs8_lr0.0001_rerun\tabla_estabilidad_por_dataset_efficientnet_b0.csv
#             Modelo     Dataset  N validaci?n  Accuracy  F1 macro  \
# 1  EfficientNet-B0  aptos_2019           105     0.571     0.558
# 0  EfficientNet-B0     eyePACS           614     0.539     0.532
# 2  EfficientNet-B0       idrid            25     0.720     0.468
#
#    Recall clase 3  Recall clase 4    QWK
# 1           0.471           0.816  0.766
# 0           0.556           0.677  0.767
# 2           0.750           0.833  0.869

# %% [markdown]
# # 10. Reportes adicionales y W&B - OPCIONAL / PUEDES SALTAR
#
# Estas celdas generan reportes globales, gr?ficos, ROC/AUC, IoU o registros en Weights & Biases. No son necesarias para la tabla por dataset.

# %% [markdown]
# ## W&B - opcional

# %%
import wandb
wandb.login()  # usa la sesi?n local o WANDB_API_KEY
wandb.login()
# Out:
# True

# %% [markdown]
# ## W&B - opcional

# %%
from pathlib import Path
import os

# === Carpeta local para archivos de W&B ===
WANDB_LOCAL_DIR = Path(r"C:\Users\Victoria\Desktop\data\datos_raw\resultados_dl\_wandb_runs")
WANDB_LOCAL_DIR.mkdir(parents=True, exist_ok=True)

# Define la variable de entorno (W&B usará esta ruta)
os.environ["WANDB_DIR"] = str(WANDB_LOCAL_DIR)

# === Inicializar el run ===
run = wandb.init(
    project="retinopatia-diabetica",
    entity="victoria-castro-universidad-peruana-cayetano-heredia",  # tu cuenta/org
    name=RUN_TAG,                                   # ejemplo: efficientnet_b0_img224_bs32_lr0.001
    tags=["DL", "CUDA", ARCH] + DATASETS,           # etiquetas reales
    dir=os.environ["WANDB_DIR"],                    # carpeta local donde se guardan los logs
    config={
        "epochs": EPOCHS,
        "batch_size": BATCH,
        "lr": LR,
        "weight_decay": WD,
        "img_size": IMG_SIZE,
        "arch": ARCH,
        "datasets": DATASETS,
        "device": str(DEVICE),
        "outdir": str(OUTDIR),
    },
)
# Out:
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>C:\Users\Victoria\Desktop\data\datos_raw\resultados_dl\_wandb_runs\wandb\run-20260630_153155-stjddibf</code>
# Syncing run <strong><a href='https://wandb.ai/victoria-castro-universidad-peruana-cayetano-heredia/retinopatia-diabetica/runs/stjddibf' target="_blank">efficientnet_b0_img384_bs8_lr0.0001_rerun</a></strong> to <a href='https://wandb.ai/victoria-castro-universidad-peruana-cayetano-heredia/retinopatia-diabetica' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/victoria-castro-universidad-peruana-cayetano-heredia/retinopatia-diabetica' target="_blank">https://wandb.ai/victoria-castro-universidad-peruana-cayetano-heredia/retinopatia-diabetica</a>
#  View run at <a href='https://wandb.ai/victoria-castro-universidad-peruana-cayetano-heredia/retinopatia-diabetica/runs/stjddibf' target="_blank">https://wandb.ai/victoria-castro-universidad-peruana-cayetano-heredia/retinopatia-diabetica/runs/stjddibf</a>

# %% [markdown]
# ## Prueba de timm - opcional

# %%
import timm
print("timm version:", timm.__version__)
print("mit_b0" in timm.list_models())
print("mit_b1" in timm.list_models())
# Out:
# timm version: 1.0.24
# False
# False

# %% [markdown]
# ## Evaluaci?n global lenta - opcional

# %%
# ----------------------------
# Evaluación en el split de validación
# ----------------------------
model.eval()
ys, ps = [], []
with torch.no_grad():
    for xb, yb in DataLoader(CSVImages(df_va, tfm_va), batch_size=BATCH, shuffle=False,
                             num_workers=NUM_WORKERS, pin_memory=PIN_MEMORY):
        xb = xb.to(DEVICE, non_blocking=True)
        pred = model(xb).argmax(1).cpu().numpy()
        ys.extend(yb.numpy().tolist()); ps.extend(pred.tolist())

rep = classification_report(ys, ps, output_dict=True, zero_division=0)
pd.DataFrame(rep).transpose().to_csv(OUTDIR/"cls_report_val.csv")

cm = confusion_matrix(ys, ps, labels=list(range(N_CLASSES)))
fig, ax = plt.subplots(figsize=(5,4), dpi=140)
im = ax.imshow(cm, cmap="viridis")
ax.set_xlabel("Predicted"); ax.set_ylabel("True"); ax.set_title("Confusion • VAL (combined)")
ax.set_xticks(range(N_CLASSES)); ax.set_yticks(range(N_CLASSES))
for i in range(N_CLASSES):
    for j in range(N_CLASSES):
        ax.text(j, i, int(cm[i, j]), ha="center", va="center",
                color="white" if cm[i,j] > cm.max()*0.6 else "black", fontsize=8)
plt.colorbar(im, fraction=0.046, pad=0.04)
plt.tight_layout(); plt.savefig(OUTDIR/"confmat_val.png", bbox_inches="tight"); plt.close()

# Log to Weights & Biases
try:
    import wandb
    wandb.log({
        "val/confusion_matrix": wandb.plot.confusion_matrix(
            y_true=ys, preds=ps, class_names=[str(i) for i in range(N_CLASSES)]
        )
    })
except Exception as e:
    print("[W&B] No se pudo loguear la matriz de confusión:", e)

# %% [markdown]
# ## Evaluaci?n global lenta - opcional

# %%
# ----------------------------
# Evaluación en el split de validación
# ----------------------------
model.eval()
ys, ps = [], []
with torch.no_grad():
    for xb, yb in DataLoader(CSVImages(df_va, tfm_va), batch_size=BATCH, shuffle=False,
                             num_workers=NUM_WORKERS, pin_memory=PIN_MEMORY):
        xb = xb.to(DEVICE, non_blocking=True)
        pred = model(xb).argmax(1).cpu().numpy()
        ys.extend(yb.numpy().tolist()); ps.extend(pred.tolist())

rep = classification_report(ys, ps, output_dict=True, zero_division=0)
pd.DataFrame(rep).transpose().to_csv(OUTDIR/"cls_report_val.csv")

cm = confusion_matrix(ys, ps, labels=list(range(N_CLASSES)))
fig, ax = plt.subplots(figsize=(5,4), dpi=140)
im = ax.imshow(cm, cmap="viridis")
ax.set_xlabel("Predicted"); ax.set_ylabel("True"); ax.set_title("Confusion • VAL (combined)")
ax.set_xticks(range(N_CLASSES)); ax.set_yticks(range(N_CLASSES))
for i in range(N_CLASSES):
    for j in range(N_CLASSES):
        ax.text(j, i, int(cm[i, j]), ha="center", va="center",
                color="white" if cm[i,j] > cm.max()*0.6 else "black", fontsize=8)
plt.colorbar(im, fraction=0.046, pad=0.04)
plt.tight_layout(); plt.savefig(OUTDIR/"confmat_val.png", bbox_inches="tight"); plt.close()

# Log to Weights & Biases
try:
    import wandb 
    wandb.log({
        "val/confusion_matrix": wandb.plot.confusion_matrix(
            y_true=ys, preds=ps, class_names=[str(i) for i in range(N_CLASSES)]
        )
    })
except Exception as e:
    print("[W&B] No se pudo loguear la matriz de confusión:", e)

# %% [markdown]
# ## Guardar configuraci?n - opcional

# %%
# ----------------------------
# Guardar config
# ----------------------------
cfg = dict(
    mode="train-only",
    datasets=DATASETS, arch=ARCH, img_size=IMG_SIZE,
    batch=BATCH, epochs=EPOCHS, lr=LR, wd=WD,
    val_size=VAL_SIZE, seed=SEED,
    balance_max=BALANCE_MAX_PER_CLASS,
    sizes=dict(train=len(df_tr), val=len(df_va)),
    device=str(DEVICE),
    class_dist_train=df_tr["level"].value_counts().sort_index().to_dict(),
    class_dist_val=df_va["level"].value_counts().sort_index().to_dict(),
)
with open(OUTDIR/"config.json","w") as f:
    json.dump(cfg, f, indent=2)

print("\n✅ Listo. Carpeta de salida:", OUTDIR.resolve())
# Out:
# ✅ Listo. Carpeta de salida: C:\Users\Victoria\Desktop\data\datos_raw\resultados_dl\COMBINED_TRAIN_ONLY_aptos_2019-eyePACS-idrid-messidor_efficientnet_b0_img384_bs8_lr0.0001_rerun

# %% [markdown]
# ## Accuracy y QWK global - opcional

# %%
from sklearn.metrics import accuracy_score, cohen_kappa_score

acc_final = accuracy_score(y_true, y_pred)
qwk_final = cohen_kappa_score(y_true, y_pred, weights="quadratic")

print(f"Accuracy final: {acc_final:.4f}")
print(f"QWK final: {qwk_final:.4f}")

wandb.log({
    "val/acc_final": float(acc_final),
    "val/qwk_final": float(qwk_final)
})
# Out:
# Accuracy final: 0.5497
# QWK final: 0.7857

# %%
import pandas as pd
from pathlib import Path

report_path = OUTDIR / "classification_report_val.csv"

rep = pd.read_csv(report_path)
rep
# Out:
#      Unnamed: 0  precision    recall  f1-score     support
# 0             0   0.506438  0.791946  0.617801  149.000000
# 1             1   0.408333  0.331081  0.365672  148.000000
# 2             2   0.490385  0.342282  0.403162  149.000000
# 3             3   0.614815  0.557047  0.584507  149.000000
# 4             4   0.710526  0.724832  0.717608  149.000000
# 5      accuracy   0.549731  0.549731  0.549731    0.549731
# 6     macro avg   0.546099  0.549438  0.537750  744.000000
# 7  weighted avg   0.546285  0.549731  0.537981  744.000000

# %% [markdown]
# ## F1 por clase - opcional

# %%
# ========= F1 macro/micro/por clase =========
from sklearn.metrics import classification_report, f1_score
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

#OUT = Path("resultados_dl"); OUT.mkdir(parents=True, exist_ok=True)
OUT = Path(OUTDIR); OUT.mkdir(parents=True, exist_ok=True)

f1_macro = f1_score(y_true, y_pred, average="macro")
f1_micro = f1_score(y_true, y_pred, average="micro")
rep = classification_report(y_true, y_pred, output_dict=True, digits=4)
rep_df = pd.DataFrame(rep).T
rep_df.to_csv(OUT / "classification_report_val.csv")

print(f"F1-macro: {f1_macro:.4f} | F1-micro: {f1_micro:.4f}")
display(rep_df)

# Gráfico de F1 por clase
cls_rows = [str(i) for i in range(N_CLASSES) if str(i) in rep_df.index]
plt.figure(figsize=(6,4))
plt.bar(cls_rows, rep_df.loc[cls_rows, "f1-score"].values)
plt.title("F1-score por clase (validación)")
plt.xlabel("Clase"); plt.ylabel("F1"); plt.ylim(0,1)
plt.tight_layout(); plt.savefig(OUT / "f1_por_clase_val.png", dpi=140); plt.show()

# Log to W&B: métricas y figura
try:
    wandb.log({
        "val/f1_macro": float(f1_macro),
        "val/f1_micro": float(f1_micro),
        "val/classification_report": wandb.Table(dataframe=rep_df.reset_index()),
        "val/f1_plot": wandb.Image(str(OUT / "f1_por_clase_val.png"))
    })
    # Subir el CSV como Artifact en lugar de usar wandb.save (evita symlink en Windows)
    try:
        artifact = wandb.Artifact("classification_report_val", type="report")
        artifact.add_file(str(OUT / "classification_report_val.csv"))
        run.log_artifact(artifact)
    except Exception as e:
        print("[W&B] Error subiendo artifact de classification_report:", e)
except Exception as e:
    print("[W&B] No se pudo loguear F1/tabla/figura:", e)
# Out:
# F1-macro: 0.5377 | F1-micro: 0.5497
#               precision    recall  f1-score     support
# 0              0.506438  0.791946  0.617801  149.000000
# 1              0.408333  0.331081  0.365672  148.000000
# 2              0.490385  0.342282  0.403162  149.000000
# 3              0.614815  0.557047  0.584507  149.000000
# 4              0.710526  0.724832  0.717608  149.000000
# accuracy       0.549731  0.549731  0.549731    0.549731
# macro avg      0.546099  0.549438  0.537750  744.000000
# weighted avg   0.546285  0.549731  0.537981  744.000000

# %% [markdown]
# ## IoU por clase - opcional

# %%
# ========= IoU (Jaccard) por clase =========
from sklearn.metrics import confusion_matrix
import numpy as np

cm = confusion_matrix(y_true, y_pred, labels=np.arange(N_CLASSES))
# TP: diagonal
TP = np.diag(cm).astype(float)
# FP: suma columna k menos TP_k
FP = cm.sum(axis=0) - TP
# FN: suma fila k menos TP_k
FN = cm.sum(axis=1) - TP
IoU = TP / np.clip(TP + FP + FN, 1e-9, None)
IoU_macro = np.nanmean(IoU)

print("IoU por clase:", {i: round(v,4) for i,v in enumerate(IoU)})
print("IoU macro   :", round(IoU_macro,4))

# Guardar CSV + gráfico
iou_df = pd.DataFrame({"clase": np.arange(N_CLASSES), "IoU": IoU})
iou_df.to_csv(OUT / "iou_por_clase_val.csv", index=False)

plt.figure(figsize=(6,4))
plt.bar(iou_df["clase"].astype(str).values, iou_df["IoU"].values)
plt.title("IoU (Jaccard) por clase (validación)")
plt.xlabel("Clase"); plt.ylabel("IoU"); plt.ylim(0,1)
plt.tight_layout(); plt.savefig(OUT / "iou_por_clase_val.png", dpi=140); plt.show()

# Log to W&B
try:
    wandb.log({
        "val/iou_macro": float(IoU_macro),
        "val/iou_by_class": wandb.Table(dataframe=iou_df),
        "val/iou_plot": wandb.Image(str(OUT / "iou_por_clase_val.png"))
    })
    # Subir CSV de IoU como Artifact (evitar wandb.save en Windows)
    try:
        artifact = wandb.Artifact("iou_por_clase_val", type="metrics")
        artifact.add_file(str(OUT / "iou_por_clase_val.csv"))
        run.log_artifact(artifact)
    except Exception as e:
        print("[W&B] Error subiendo artifact de IoU:", e)
    
except Exception as e:
    print("[W&B] No se pudo loguear IoU:", e)
# Out:
# IoU por clase: {0: np.float64(0.4071), 1: np.float64(0.2876), 2: np.float64(0.3333), 3: np.float64(0.4036), 4: np.float64(0.5145)}
# IoU macro   : 0.3892

# %% [markdown]
# ## ROC/AUC - opcional

# %%
# ========= ROC/AUC multi-clase =========
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc, roc_auc_score

# binariza y_true a one-hot
y_true_bin = label_binarize(y_true, classes=np.arange(N_CLASSES))  # (N, C)

# AUC macro/micro (usando probabilidades por clase)
auc_macro = roc_auc_score(y_true_bin, y_prob, average="macro", multi_class="ovr")
auc_micro = roc_auc_score(y_true_bin, y_prob, average="micro", multi_class="ovr")
print(f"AUC macro: {auc_macro:.4f} | AUC micro: {auc_micro:.4f}")

# Curvas ROC por clase (one-vs-rest)
plt.figure(figsize=(7,6))
for k in range(N_CLASSES):
    fpr, tpr, _ = roc_curve(y_true_bin[:, k], y_prob[:, k])
    cls_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"Clase {k} (AUC={cls_auc:.3f})")

plt.plot([0,1],[0,1],"--", lw=1, color="gray")
plt.xlabel("FPR"); plt.ylabel("TPR")
plt.title("ROC por clase (validación) · OVR")
plt.legend(loc="lower right")
plt.tight_layout(); plt.savefig(OUT / "roc_ovr_val.png", dpi=140); plt.show()

# Log to W&B: AUCs + figura
try:
    wandb.log({
        "val/auc_macro": float(auc_macro),
        "val/auc_micro": float(auc_micro),
        "val/roc_plot": wandb.Image(str(OUT / "roc_ovr_val.png"))
    })
except Exception as e:
    print("[W&B] No se pudo loguear ROC/AUC:", e)
# Out:
# AUC macro: 0.8388 | AUC micro: 0.8500

# %%
from sklearn.metrics import confusion_matrix, recall_score
import numpy as np
import matplotlib.pyplot as plt

class_names = ["No RD", "Leve", "Moderado", "Severo", "PRD"]

cm = confusion_matrix(y_true, y_pred, labels=np.arange(5))
cm_norm = cm / cm.sum(axis=1, keepdims=True)

# Matriz absoluta
fig, ax = plt.subplots(figsize=(6, 5), dpi=160)
im = ax.imshow(cm, cmap="viridis")
ax.set_title("Matriz de confusión absoluta - EfficientNet-B0")
ax.set_xlabel("Clase predicha")
ax.set_ylabel("Clase real")
ax.set_xticks(np.arange(5))
ax.set_yticks(np.arange(5))
ax.set_xticklabels(class_names, rotation=45, ha="right")
ax.set_yticklabels(class_names)

for i in range(5):
    for j in range(5):
        ax.text(
            j, i, int(cm[i, j]),
            ha="center", va="center",
            color="white" if cm[i, j] > cm.max() * 0.6 else "black",
            fontsize=8
        )

plt.colorbar(im, fraction=0.046, pad=0.04)
plt.tight_layout()
plt.savefig(OUTDIR / "efficientnet_b0_matriz_absoluta.png", dpi=160, bbox_inches="tight")
plt.show()

# Matriz normalizada
fig, ax = plt.subplots(figsize=(6, 5), dpi=160)
im = ax.imshow(cm_norm, cmap="viridis", vmin=0, vmax=1)
ax.set_title("Matriz de confusión normalizada por fila - EfficientNet-B0")
ax.set_xlabel("Clase predicha")
ax.set_ylabel("Clase real")
ax.set_xticks(np.arange(5))
ax.set_yticks(np.arange(5))
ax.set_xticklabels(class_names, rotation=45, ha="right")
ax.set_yticklabels(class_names)

for i in range(5):
    for j in range(5):
        ax.text(
            j, i, f"{cm_norm[i, j]:.2f}",
            ha="center", va="center",
            color="white" if cm_norm[i, j] > 0.6 else "black",
            fontsize=8
        )

plt.colorbar(im, fraction=0.046, pad=0.04)
plt.tight_layout()
plt.savefig(OUTDIR / "efficientnet_b0_matriz_normalizada.png", dpi=160, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Cerrar W&B - opcional

# %%
try:
    run.finish()
except Exception:
    pass
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▂▃▄▄▅▅▆▇▇█</td></tr><tr><td>lr</td><td>██████████▁▁</td></tr><tr><td>train/loss</td><td>█▆▅▄▄▃▂▂▂▂▁▁</td></tr><tr><td>val/acc</td><td>▁▅▅▃▅▆▆▇▅▇▆█</td></tr><tr><td>val/acc_final</td><td>▁</td></tr><tr><td>val/auc_macro</td><td>▁</td></tr><tr><td>val/auc_micro</td><td>▁</td></tr><tr><td>val/f1_macro</td><td>▁</td></tr><tr><td>val/f1_micro</td><td>▁</td></tr><tr><td>val/iou_macro</td><td>▁</td></tr><tr><td>+3</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>12</td></tr><tr><td>lr</td><td>5e-05</td></tr><tr><td>train/loss</td><td>1.36944</td></tr><tr><td>val/acc</td><td>0.588</td></tr><tr><td>val/acc_final</td><td>0.55333</td></tr><tr><td>val/auc_macro</td><td>0.85698</td></tr><tr><td>val/auc_micro</td><td>0.86046</td></tr><tr><td>val/f1_macro</td><td>0.55596</td></tr><tr><td>val/f1_micro</td><td>0.55333</td></tr><tr><td>val/iou_macro</td><td>0.38921</td></tr><tr><td>+3</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">efficientnet_b0_img384_bs8_lr0.0001_rerun</strong> at: <a href='https://wandb.ai/victoria-castro-universidad-peruana-cayetano-heredia/retinopatia-diabetica/runs/lnub1m44' target="_blank">https://wandb.ai/victoria-castro-universidad-peruana-cayetano-heredia/retinopatia-diabetica/runs/lnub1m44</a><br> View project at: <a href='https://wandb.ai/victoria-castro-universidad-peruana-cayetano-heredia/retinopatia-diabetica' target="_blank">https://wandb.ai/victoria-castro-universidad-peruana-cayetano-heredia/retinopatia-diabetica</a><br>Synced 5 W&B file(s), 13 media file(s), 22 artifact file(s) and 0 other file(s)
# Find logs at: <code>C:\Users\Victoria\Desktop\data\datos_raw\resultados_dl\_wandb_runs\wandb\run-20260423_180753-lnub1m44\logs</code>
